# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruoro/G2M_INSIGHTS/blob/main/G2M_Insight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # G2M INSIGHTS
#
# ---

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# XYZ is a private firm in US. Due to remarkable growth in the Cab Industry in last few years and multiple key players in the market, it is planning for an investment in Cab industry and as per their Go-to-Market(G2M) strategy they want to understand the market before taking final decision.

# %% [markdown]
# ## 2. Data understanding

# %% [markdown]
# ### Import libraries and dependancies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

# %%
# load the data 
cab = pd.read_csv('Cab_Data.csv')
city = pd.read_csv('City.csv')
customer = pd.read_csv('Customer_ID.csv')
transaction = pd.read_csv('Transaction_ID.csv')  
print('Successfully Read Data')
# Out:
# Successfully Read Data

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# ##### CAB

# %%
# Preview the cab dataset
cab.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
# preview data shape
cab.shape
# Out:
# (359392, 7)

# %%
# preview the stats of the df
cab.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
# Find out the df column names
cab.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip'],
#       dtype='object')

# %%
# Finding the type of data in each column
cab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %% [markdown]
# ##### CITY

# %%
# Preview the city dataset
city.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
# preview data shape
city.shape
# Out:
# (20, 3)

# %%
# preview the stats of the df
city.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
# Find out the df column names
city.columns
# Out:
# Index(['City', 'Population', 'Users'], dtype='object')

# %%
# Finding the type of data in each column
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %% [markdown]
# ##### CUSTOMER

# %%
# Preview the customer dataset
customer.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
# preview data shape
customer.shape
# Out:
# (49171, 4)

# %%
# preview the stats of the df
customer.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
# Find out the df column names
customer.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Income (USD/Month)'], dtype='object')

# %%
# Finding the type of data in each column
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# ##### TRANSACTIONS

# %%
# Preview the Trasaction dataset
transaction.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
# preview data shape
transaction.shape
# Out:
# (440098, 3)

# %%
# preview the stats of the df
transaction.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
# Find out the df column names
transaction.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Payment_Mode'], dtype='object')

# %%
# Finding the type of data in each column
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %% [markdown]
# ## 3. Data Preparation

# %%
# check for missing values in all the data sets 
print("The missing values in the Cab dataset are: ", cab.isna().sum())
print("\n The missing values in the City dataset are: ", city.isna().sum())
print("\n The missing values in the Customer dataset are: ", customer.isna().sum())
print("\n The missing values in the Transactions dataset are: ", transaction.isna().sum())
# Out:
# The missing values in the Cab dataset are:  Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64
#
#  The missing values in the City dataset are:  City          0
# Population    0
# Users         0
# dtype: int64
#
#  The missing values in the Customer dataset are:  Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64
#
#  The missing values in the Transactions dataset are:  Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %% [markdown]
# There are no missing values but there is a need to concact the datasets together to get better insigts from the data.
#
#
# > In addition to merging the provided data, I thought I would add two more files to the data namely:
#
#
# > 1.   Holiday dataset
# > 2.   weather dataset

# %% [markdown]
# #### Holiday csv

# %%
# adding the holiday csv and previewing it 
holiday = pd.read_csv('holiday.csv')
holiday.head()
# Out:
#          Date                           Name_Holiday
# 0  2016-01-18             Martin Luther King Jr. Day
# 1  2016-02-15  Presidents Day (Washingtons Birthday)
# 2  2016-05-30                           Memorial Day
# 3  2016-07-04                       Independence Day
# 4  2016-09-05                              Labor Day

# %%
holiday.shape
# Out:
# (29, 2)

# %%
holiday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          29 non-null     object
#  1   Name_Holiday  29 non-null     object
# dtypes: object(2)
# memory usage: 592.0+ bytes

# %%
holiday.describe()
# Out:
#               Date                Name_Holiday
# count           29                          29
# unique          29                          10
# top     2016-01-18  Martin Luther King Jr. Day
# freq             1                           3

# %% [markdown]
# #### Weather Events

# %%
# Adding the weather dataset
weather = pd.read_csv('weather_events.csv')
weather.head()
# Out:
#    EventId  Type Severity        Date  LocationLat  LocationLng State
# 0        1  Rain    Light  2016-01-01      30.3371     -81.5127    FL
# 1        2  Rain    Light  2016-01-02      29.7086     -98.0453    TX
# 2        3  Rain    Light  2016-01-03      28.6150     -80.6945    FL
# 3        4  Cold   Severe  2016-01-04      44.3853     -74.2062    NY
# 4        5  Rain    Light  2016-01-05      35.6694    -120.6291    CA

# %%
# Check for the shape
weather.shape
# Out:
# (1095, 7)

# %%
# column names
weather.columns
# Out:
# Index(['EventId', 'Type', 'Severity', 'Date', 'LocationLat', 'LocationLng',
#        'State'],
#       dtype='object')

# %%
# Severity levels
weather['Severity'].unique()
# Out:
# array(['Light', 'Severe', 'Moderate', 'Heavy', 'UNK', 'Other'],
#       dtype=object)

# %%
# Different weather patterns
weather['Type'].unique()
# Out:
# array(['Rain', 'Cold', 'Fog', 'Snow', 'Precipitation', 'Storm', 'Hail'],
#       dtype=object)

# %% [markdown]
# #### merging the data

# %% [markdown]
# Based on the previous analysis, the different dataframes have several relationships. Therefore, I need the column of each data frame to be of the same type. Now I need to make sure of that.
#
# - First, I'll merge this two dataframes(Holydays and WeatherEvents_Jan2016-Dec2018)
#
# - Second, I'll merge this four dataframes(Customer_ID, Transaction_ID, Cab_Data and City)
#
# - Third, I'll merge the result of that two dataframe that I have merged before

# %% [markdown]
# The Weather and the holiday dates are not parsed in the correct fomart therefore we have to fix that.
#
# Also the data in the date of travel in the cab data is not correctly parsed

# %%
# Converting the date data to apprpriate data type
weather['Date'] = pd.to_datetime(weather["Date"])
holiday['Date'] = pd.to_datetime(holiday["Date"])
print ("Converted successfully")
# Out:
# Converted successfully

# %%
# confirming
print(weather.info())
print(holiday.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EventId      1095 non-null   int64
#  1   Type         1095 non-null   object
#  2   Severity     1095 non-null   object
#  3   Date         1095 non-null   datetime64[ns]
#  4   LocationLat  1095 non-null   float64
#  5   LocationLng  1095 non-null   float64
#  6   State        1095 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 60.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          29 non-null     datetime64[ns]
#  1   Name_Holiday  29 non-null     object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 592.0+ bytes
# None

# %%
# imports
from datetime import date, timedelta, datetime

# conversion
cab['Date of Travel'] = cab['Date of Travel'].map(lambda x: (date(1899,12,30) + timedelta(days=x)).strftime("%Y-%m-%d"))
cab['Date of Travel'] = pd.to_datetime(cab['Date of Travel'])
cab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  datetime64[ns]
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 19.2+ MB

# %%
# first merge
first =holiday.merge(weather, on='Date', how="right")
first.columns
# Out:
# Index(['Date', 'Name_Holiday', 'EventId', 'Type', 'Severity', 'LocationLat',
#        'LocationLng', 'State'],
#       dtype='object')

# %%
# second merge
second =customer.merge(transaction, on='Customer ID').merge(cab, on='Transaction ID').merge(city, on='City')
second.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Income (USD/Month)', 'Transaction ID',
#        'Payment_Mode', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Population', 'Users'],
#       dtype='object')

# %%
# final merge
df_final=second.merge(first, left_on="Date of Travel", right_on="Date",how='left')
print(df_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Customer ID         359392 non-null  int64
#  1   Gender              359392 non-null  object
#  2   Age                 359392 non-null  int64
#  3   Income (USD/Month)  359392 non-null  int64
#  4   Transaction ID      359392 non-null  int64
#  5   Payment_Mode        359392 non-null  object
#  6   Date of Travel      359392 non-null  datetime64[ns]
#  7   Company             359392 non-null  object
#  8   City                359392 non-null  object
#  9   KM Travelled        359392 non-null  float64
#  10  Price Charged       359392 non-null  float64
#  11  Cost of Trip        359392 non-null  float64
#  12  Population          359392 non-null  object
#  13  Users               359392 non-null  object
#  14  Date                359136 non-null  datetime64[ns]
#  15  Name_Holiday        7577 non-null    object
#  16  EventId             359136 non-null  float64
#  17  Type                359136 non-null  object
#  18  Severity            359136 non-null  object
#  19  LocationLat         359136 non-null  float64
#  20  LocationLng         359136 non-null  float64
#  21  State               359136 non-null  object
# dtypes: datetime64[ns](2), float64(6), int64(4), object(10)
# memory usage: 63.1+ MB
# None

# %% [markdown]
# #### Exploring the final dataframe

# %%
# check the shape
df_final.shape
# Out:
# (359392, 22)

# %%
df_final.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card
#
#   Date of Travel     Company        City  KM Travelled  ...  Population  \
# 0     2016-01-08    Pink Cab  ATLANTA GA         30.45  ...    814,885
# 1     2018-07-21  Yellow Cab  ATLANTA GA         26.19  ...    814,885
# 2     2018-11-23  Yellow Cab  ATLANTA GA         42.55  ...    814,885
# 3     2016-01-06    Pink Cab  ATLANTA GA         28.62  ...    814,885
# 4     2018-04-21  Yellow Cab  ATLANTA GA         36.38  ...    814,885
#
#       Users       Date Name_Holiday EventId  Type  Severity LocationLat  \
# 0   24,701  2016-01-08          NaN     8.0  Rain     Light     27.9633
# 1   24,701  2018-07-21          NaN   933.0  Rain     Light     42.1933
# 2   24,701  2018-11-23          NaN  1058.0   Fog  Moderate     36.8933
# 3   24,701  2016-01-06          NaN     6.0  Rain     Light     36.9394
# 4   24,701  2018-04-21          NaN   842.0  Snow     Light     39.7852
#
#   LocationLng  State
# 0    -82.5400     FL
# 1    -89.0933     IL
# 2   -121.4103     CA
# 3   -121.7900     CA
# 4   -104.5431     CO
#
# [5 rows x 22 columns]

# %% [markdown]
# There are some null characters in the data set.

# %%
# check the number of missing values
df_final.isnull().sum()
# Out:
# Customer ID                0
# Gender                     0
# Age                        0
# Income (USD/Month)         0
# Transaction ID             0
# Payment_Mode               0
# Date of Travel             0
# Company                    0
# City                       0
# KM Travelled               0
# Price Charged              0
# Cost of Trip               0
# Population                 0
# Users                      0
# Date                     256
# Name_Holiday          351815
# EventId                  256
# Type                     256
# Severity                 256
# LocationLat              256
# LocationLng              256
# State                    256
# dtype: int64

# %% [markdown]
# The number of missing variables is what should be expected but we should still clean the dataset to derive good insights.

# %%
# check the number of unique valuesin the dataset
df_final.nunique()
# Out:
# Customer ID            46148
# Gender                     2
# Age                       48
# Income (USD/Month)     22725
# Transaction ID        359392
# Payment_Mode               2
# Date of Travel          1095
# Company                    2
# City                      19
# KM Travelled             874
# Price Charged          99176
# Cost of Trip           16291
# Population                19
# Users                     19
# Date                    1094
# Name_Holiday              10
# EventId                 1094
# Type                       7
# Severity                   6
# LocationLat              544
# LocationLng              546
# State                     13
# dtype: int64

# %%
df_final.describe()
# Out:
#          Customer ID            Age  Income (USD/Month)  Transaction ID  \
# count  359392.000000  359392.000000       359392.000000    3.593920e+05
# mean    19191.652115      35.336705        15048.822937    1.022076e+07
# std     21012.412463      12.594234         7969.409482    1.268058e+05
# min         1.000000      18.000000         2000.000000    1.000001e+07
# 25%      2705.000000      25.000000         8424.000000    1.011081e+07
# 50%      7459.000000      33.000000        14685.000000    1.022104e+07
# 75%     36078.000000      42.000000        21035.000000    1.033094e+07
# max     60000.000000      65.000000        35000.000000    1.044011e+07
#
#         KM Travelled  Price Charged   Cost of Trip        EventId  \
# count  359392.000000  359392.000000  359392.000000  359136.000000
# mean       22.567254     423.443311     286.190113     594.710923
# std        12.233526     274.378911     157.993661     307.285643
# min         1.900000      15.600000      19.000000       2.000000
# 25%        12.000000     206.437500     151.200000     328.000000
# 50%        22.440000     386.360000     282.480000     618.000000
# 75%        32.960000     583.660000     413.683200     862.000000
# max        48.000000    2048.030000     691.200000    1095.000000
#
#          LocationLat    LocationLng
# count  359136.000000  359136.000000
# mean       36.822174     -94.940477
# std         5.826554      16.332682
# min        24.557100    -124.555000
# 25%        31.920600    -106.168900
# 50%        37.182400     -90.110100
# 75%        41.025400     -81.335400
# max        48.799100     -69.993300

# %% [markdown]
# From the Analysis we can see that:
# - population needs to be changed to int data type
# - turn users into int data type
# - In Name_Holiday column i will fill it the NaN values with "Not a Holiday"
# - Separate Date of Travel column in Month and Year column:
#
#   - Date of Travel --> Month
#
#   - Date of Travel --> Year
#
# - Drop the null values
# - Drop irrelevant columns

# %%
# Separate the month and year columns
df_final["Month"]=df_final["Date of Travel"].map(lambda x: x.month)
df_final["Year"]=df_final["Date of Travel"].map(lambda x: x.year)

# %%
df_final.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card
#
#   Date of Travel     Company        City  KM Travelled  ...       Date  \
# 0     2016-01-08    Pink Cab  ATLANTA GA         30.45  ... 2016-01-08
# 1     2018-07-21  Yellow Cab  ATLANTA GA         26.19  ... 2018-07-21
# 2     2018-11-23  Yellow Cab  ATLANTA GA         42.55  ... 2018-11-23
# 3     2016-01-06    Pink Cab  ATLANTA GA         28.62  ... 2016-01-06
# 4     2018-04-21  Yellow Cab  ATLANTA GA         36.38  ... 2018-04-21
#
#    Name_Holiday EventId  Type  Severity LocationLat  LocationLng State Month  \
# 0           NaN     8.0  Rain     Light     27.9633     -82.5400    FL     1
# 1           NaN   933.0  Rain     Light     42.1933     -89.0933    IL     7
# 2           NaN  1058.0   Fog  Moderate     36.8933    -121.4103    CA    11
# 3           NaN     6.0  Rain     Light     36.9394    -121.7900    CA     1
# 4           NaN   842.0  Snow     Light     39.7852    -104.5431    CO     4
#
#    Year
# 0  2016
# 1  2018
# 2  2018
# 3  2016
# 4  2018
#
# [5 rows x 24 columns]

# %% [markdown]
# Dropping irrelevant columns
# - Customer ID
# - Transaction ID
# - EventId
# - LocationLat
# - LocationLng
# - State

# %%
drop_cols=['EventId', 'Severity', 'LocationLat', 'LocationLng',"Date of Travel", 'Date', "State"]
df_final.drop(columns=drop_cols, inplace=True)

# %%
df_final.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card
#
#       Company        City  KM Travelled  Price Charged  Cost of Trip  \
# 0    Pink Cab  ATLANTA GA         30.45         370.95      313.6350
# 1  Yellow Cab  ATLANTA GA         26.19         598.70      317.4228
# 2  Yellow Cab  ATLANTA GA         42.55         792.05      597.4020
# 3    Pink Cab  ATLANTA GA         28.62         358.52      334.8540
# 4  Yellow Cab  ATLANTA GA         36.38         721.10      467.1192
#
#   Population     Users Name_Holiday  Type  Month  Year
# 0   814,885    24,701           NaN  Rain      1  2016
# 1   814,885    24,701           NaN  Rain      7  2018
# 2   814,885    24,701           NaN   Fog     11  2018
# 3   814,885    24,701           NaN  Rain      1  2016
# 4   814,885    24,701           NaN  Snow      4  2018

# %% [markdown]
# convering the population and users to int

# %%
# removing the spaces and the commas in the values
# Removing commas
df_final['Population'] = df_final['Population'].str.replace(',', '') 
df_final['Users'] = df_final['Users'].str.replace(',', '')

# converting to numeric
df_final['Population'] = pd.to_numeric(df_final['Population'])
df_final['Users'] = pd.to_numeric(df_final['Users'])

df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Customer ID         359392 non-null  int64
#  1   Gender              359392 non-null  object
#  2   Age                 359392 non-null  int64
#  3   Income (USD/Month)  359392 non-null  int64
#  4   Transaction ID      359392 non-null  int64
#  5   Payment_Mode        359392 non-null  object
#  6   Company             359392 non-null  object
#  7   City                359392 non-null  object
#  8   KM Travelled        359392 non-null  float64
#  9   Price Charged       359392 non-null  float64
#  10  Cost of Trip        359392 non-null  float64
#  11  Population          359392 non-null  int64
#  12  Users               359392 non-null  int64
#  13  Name_Holiday        7577 non-null    object
#  14  Type                359136 non-null  object
#  15  Month               359392 non-null  int64
#  16  Year                359392 non-null  int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 49.4+ MB

# %% [markdown]
# Success

# %% [markdown]
# finding the profit of the cab ride

# %%
# Calculating profit
df_final['Profit'] = df_final['Price Charged'] - df_final['Cost of Trip']
df_final.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card
#
#       Company        City  KM Travelled  Price Charged  Cost of Trip  \
# 0    Pink Cab  ATLANTA GA         30.45         370.95      313.6350
# 1  Yellow Cab  ATLANTA GA         26.19         598.70      317.4228
# 2  Yellow Cab  ATLANTA GA         42.55         792.05      597.4020
# 3    Pink Cab  ATLANTA GA         28.62         358.52      334.8540
# 4  Yellow Cab  ATLANTA GA         36.38         721.10      467.1192
#
#    Population  Users Name_Holiday  Type  Month  Year    Profit
# 0      814885  24701          NaN  Rain      1  2016   57.3150
# 1      814885  24701          NaN  Rain      7  2018  281.2772
# 2      814885  24701          NaN   Fog     11  2018  194.6480
# 3      814885  24701          NaN  Rain      1  2016   23.6660
# 4      814885  24701          NaN  Snow      4  2018  253.9808

# %% [markdown]
# Replacing the NAN on Name_Holiday to not a holiday

# %%
# check the unique values of holiday
df_final['Name_Holiday'].unique()
# Out:
# array([nan, 'New Year Day', 'Martin Luther King Jr. Day', 'Memorial Day',
#        'Veterans Day', 'Independence Day', 'Labor Day',
#        'Presidents Day (Washingtons Birthday)', 'Christmas Day',
#        'Thanksgiving Day', 'Columbus Day'], dtype=object)

# %%
# Replacing None with a value
df_final['Name_Holiday'].fillna("Not a Holiday", inplace = True)
df_final.Name_Holiday.unique()
# Out:
# array(['Not a Holiday', 'New Year Day', 'Martin Luther King Jr. Day',
#        'Memorial Day', 'Veterans Day', 'Independence Day', 'Labor Day',
#        'Presidents Day (Washingtons Birthday)', 'Christmas Day',
#        'Thanksgiving Day', 'Columbus Day'], dtype=object)

# %%
# Check the missing values
df_final.isna().sum()
# Out:
# Customer ID             0
# Gender                  0
# Age                     0
# Income (USD/Month)      0
# Transaction ID          0
# Payment_Mode            0
# Company                 0
# City                    0
# KM Travelled            0
# Price Charged           0
# Cost of Trip            0
# Population              0
# Users                   0
# Name_Holiday            0
# Type                  256
# Month                   0
# Year                    0
# Profit                  0
# dtype: int64

# %% [markdown]
# There are a few missing values in the type column

# %%
# check the values of the columns
df_final['Type'].unique()
# Out:
# array(['Rain', 'Fog', 'Snow', 'Storm', 'Cold', 'Precipitation', nan,
#        'Hail'], dtype=object)

# %%
df_final.shape
# Out:
# (359392, 18)

# %% [markdown]
# Since there are only 256 missing values in a data set of 359,000 entries it would not affect the analysis if we droped the columns

# %%
# Droping Null values
df_final.dropna(inplace = True)
df_final.shape
# Out:
# (359136, 18)

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Hypothesis to investigate
# 1. Which company has maximum cab users at a particular time period?
#
# 2. Does margin proportionally increase with increase in number of customers?
#
# 3. What are the attributes of these customer segments?

# %%
df_final.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card
#
#       Company        City  KM Travelled  Price Charged  Cost of Trip  \
# 0    Pink Cab  ATLANTA GA         30.45         370.95      313.6350
# 1  Yellow Cab  ATLANTA GA         26.19         598.70      317.4228
# 2  Yellow Cab  ATLANTA GA         42.55         792.05      597.4020
# 3    Pink Cab  ATLANTA GA         28.62         358.52      334.8540
# 4  Yellow Cab  ATLANTA GA         36.38         721.10      467.1192
#
#    Population  Users   Name_Holiday  Type  Month  Year    Profit
# 0      814885  24701  Not a Holiday  Rain      1  2016   57.3150
# 1      814885  24701  Not a Holiday  Rain      7  2018  281.2772
# 2      814885  24701  Not a Holiday   Fog     11  2018  194.6480
# 3      814885  24701  Not a Holiday  Rain      1  2016   23.6660
# 4      814885  24701  Not a Holiday  Snow      4  2018  253.9808

# %%
# Gender pie chart 

# plt.pie(df_final['Gender'].value_counts(), explode = (0.1, 0.1), shadow = True)
# plt.legend()
# plt.title('Gender of Customers')
plot = df_final['Gender'].value_counts().plot(kind='pie', autopct='%.2f %%',figsize=(6, 6), title='Gender', explode = (0.1, 0.1), shadow = True)

# %%
df_final['Gender'].value_counts()
# Out:
# Male      205767
# Female    153369
# Name: Gender, dtype: int64

# %% [markdown]
# ##### Based on Year

# %%
# Which company has maximum cab users at a particular time period?
# Grouping the dataframe to get the infomation of maximum users in both companies in yearly time periods. 
max_users = df_final.groupby(['Year', "Company"])['Users'].sum()
max_users
# Out:
# Year  Company
# 2016  Pink Cab       3133195861
#       Yellow Cab    13833515053
# 2017  Pink Cab       3826605399
#       Yellow Cab    16605163223
# 2018  Pink Cab       3672440964
#       Yellow Cab    15806008790
# Name: Users, dtype: int64

# %%
# Plotting the maximum users in pie charts
first_year = max_users.get(key=2016)
second_year = max_users.get(key=2017)
third_year = max_users.get(key=2018)
# creating fig axes
fig, axs = plt.subplots(1,3, figsize=(18,18))

#ploting pie charts
first_year.plot(kind = 'pie', autopct='%.2f %%', title='Pie chart of 2016 users', ax=axs[0])
second_year.plot(kind = 'pie', autopct='%.2f %%', title='Pie chart of 2017 users', ax=axs[1])
third_year.plot(kind = 'pie', autopct='%.2f %%', title='Pie chart of 2018 users', ax=axs[2])

# %% [markdown]
# The yellow cab company retained most of their users through out the three years. With percentage of >80% for all the three years
#
# The Pink cab had fewer users but the company was slowly growing with a 0.38 % increase in users for the three years.

# %% [markdown]
# ##### Based on Holiday Event

# %%
# Creating the series
hol_season = df_final.groupby(['Name_Holiday', "Company"])['Users'].sum()
hol_season
# Out:
# Name_Holiday                           Company
# Christmas Day                          Pink Cab         42806428
#                                        Yellow Cab      169715762
# Columbus Day                           Pink Cab         25184653
#                                        Yellow Cab       79160022
# Independence Day                       Pink Cab         12095307
#                                        Yellow Cab       53571749
# Labor Day                              Pink Cab         21268437
#                                        Yellow Cab       82040511
# Martin Luther King Jr. Day             Pink Cab          7343907
#                                        Yellow Cab       45247031
# Memorial Day                           Pink Cab         13819838
#                                        Yellow Cab       55449260
# New Year Day                           Pink Cab         19389331
#                                        Yellow Cab       75398911
# Not a Holiday                          Pink Cab      10387383715
#                                        Yellow Cab    45294050104
# Presidents Day (Washingtons Birthday)  Pink Cab          4788825
#                                        Yellow Cab       51193170
# Thanksgiving Day                       Pink Cab         43584055
#                                        Yellow Cab      146361968
# Veterans Day                           Pink Cab         54577728
#                                        Yellow Cab      192498578
# Name: Users, dtype: int64

# %%
# Plotting the Bar chart. 
hol_season.unstack().plot(kind = "bar", stacked = True ,figsize = (12, 7), title = "Bar Plot of Cabs in different Holiday Seasons")

# %% [markdown]
# We can see that there are many people who use the Yellow Cab in the seasons that are not in the holidays. It is not easy to see the difference in the holiday seasons.

# %%
#making a series without the Not a Holiday values
new_hols = hol_season.drop(labels=['Not a Holiday'])

# Bar plot of the values of the holiday events
new_hols.unstack().plot(kind = "bar", figsize = (12, 7), stacked = True, title = "Bar Plot of Cabs in different Holiday Seasons", )

# %% [markdown]
# The Yello cab has more users regardless of the time period.

# %% [markdown]
# ##### Based on Weather Event

# %%
# building a series based on the group of the weather event
wevent= df_final.groupby(["Type", "Company"])["Users"].sum()
wevent
# Out:
# Type           Company
# Cold           Pink Cab        318376888
#                Yellow Cab     1302390266
# Fog            Pink Cab       2554235552
#                Yellow Cab    10955740280
# Hail           Pink Cab         14697110
#                Yellow Cab       64198978
# Precipitation  Pink Cab        117258721
#                Yellow Cab      514044758
# Rain           Pink Cab       6759549635
#                Yellow Cab    29396185327
# Snow           Pink Cab        786474302
#                Yellow Cab     3654153207
# Storm          Pink Cab         81650016
#                Yellow Cab      357974250
# Name: Users, dtype: int64

# %%
# ploting a Bar chart with the infomation
wevent.unstack().plot(kind = "bar", figsize = (12,6),stacked = True, title = "Stacked bar chart of the No. of Users for the cab companies")

# %% [markdown]
# People used the cabs more often in the times of Rain and Fog.
# > The cab with the most users is the Yellow Cab

# %%
# Does margin proportionally increase with increase in number of customers?
df_final.head(3)
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
#
#       Company        City  KM Travelled  Price Charged  Cost of Trip  \
# 0    Pink Cab  ATLANTA GA         30.45         370.95      313.6350
# 1  Yellow Cab  ATLANTA GA         26.19         598.70      317.4228
# 2  Yellow Cab  ATLANTA GA         42.55         792.05      597.4020
#
#    Population  Users   Name_Holiday  Type  Month  Year    Profit
# 0      814885  24701  Not a Holiday  Rain      1  2016   57.3150
# 1      814885  24701  Not a Holiday  Rain      7  2018  281.2772
# 2      814885  24701  Not a Holiday   Fog     11  2018  194.6480

# %%
# Lets check the profitability of the two companies
overal_pr = df_final.groupby(['Company'])['Profit'].sum()
overal_pr.plot(kind = "bar")

# %% [markdown]
# ## 5. Evaluation

# %%
sns.pairplot(df_final)
